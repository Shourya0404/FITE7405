# %%
import os
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from AmericanOption import American
from BasketOption import Basket
from AsianOption import Asian
title= 'Arithmetic Basket'

# %% [markdown]
# ### How Strike Price Affects Call Option Price

# %%
S = [50, 50]
t = 0
T = 0.5
sigma = [0.3, 0.3]
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for K in range(10,100,10):
    C=Basket(S,K,T,sigma,r,rho,'call',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(K)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Strike Price')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Strike Price Affects Put Option price

# %%
S = [50, 50]
t = 0
T = 0.5
sigma = [0.3, 0.3]
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for K in range(10,100,10):
    C=Basket(S,K,T,sigma,r,rho,'put',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(K)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Strike Price')
# naming the y axis
plt.ylabel('Put Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Maturity Affects Call Option Price

# %%
S = [50,50]
K= 50
t = 0
sigma = [0.3,0.3]
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for T in range(1,40,1):
    T=T*0.2
    C=Basket(S,K,T,sigma,r,rho,'call',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(T)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Maturity')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Maturity Affects Put Option Price

# %%
S = [50,50]
K= 50
t = 0
sigma = [0.3,0.3]
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for T in range(1,40,1):
    T=T*0.2
    C=Basket(S,K,T,sigma,r,rho,'put',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(T)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Maturity')
# naming the y axis
plt.ylabel('Put Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Volatility Affects Call Option Price

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=[11, 9])

fig.suptitle(title+ ' Option')
fig.align_labels()

S = [50,50]
K= 38
t = 0
T=0.5
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    C=Basket(S,K,T,[sigma,0.1],r,rho,'call',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma)
ax[0].plot(param,price, label = 'ITM', color='r')
ax[0].set_ylabel('Call Option price')

S = [50,50]
K= 50
t = 0
T=0.5
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    C=Basket(S,K,T,[sigma,0.1],r,rho,'call',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma)
ax[1].plot(param,price, label = 'ATM', color='b')
ax[1].set_ylabel('Call Option price')

S = [50,50]
K= 60
t = 0
T=0.5
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    C=Basket(S,K,T,[sigma,0.1],r,rho,'call',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma)
ax[2].plot(param,price, label = 'OTM', color='g')
ax[2].set_ylabel('Call Option price')


fig.legend(loc='upper left')
plt.xlabel('Volatility')
# Out:
# Text(0.5, 0, 'Volatility')

# %% [markdown]
# ### How Volatility Affects Put Option Price

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=[11, 9])

fig.suptitle(title+ ' Option')
fig.align_labels()

S = [50,50]
K= 60
t = 0
T=0.5
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    C=Basket(S,K,T,[sigma,0.1],r,rho,'put',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma)
ax[0].plot(param,price, label = 'ITM', color='r')
ax[0].set_ylabel('Put Option price')

S = [50,50]
K= 50
t = 0
T=0.5
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    C=Basket(S,K,T,[sigma,0.1],r,rho,'put',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma)
ax[1].plot(param,price, label = 'ATM', color='b')
ax[1].set_ylabel('Put Option price')

S = [50,50]
K= 40
t = 0
T=0.5
r = 0.01
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    C=Basket(S,K,T,[sigma,0.1],r,rho,'put',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma)
ax[2].plot(param,price, label = 'OTM', color='g')
ax[2].set_ylabel('Put Option price')


fig.legend(loc='upper left')
plt.xlabel('Volatility')
# Out:
# Text(0.5, 0, 'Volatility')

# %% [markdown]
# ### How Risk Free Rate Affects Call Option Price

# %%
S = [50,50]
K= 50
t = 0
T=0.5
sigma=[0.3,0.3]
rho = 0.5
M = 10**5
price=[]
param=[]
for r in range(1,40,1):
    r=r*0.01
    C=Basket(S,K,T,sigma,r,rho,'call', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(r)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Risk Free Rate')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+ ' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Risk Free Rate Affects Put Option Price

# %%
S = [50,50]
K= 50
t = 0
T=0.5
sigma=[0.3,0.3]
rho = 0.5
M = 10**5
price=[]
param=[]
for r in range(1,40,1):
    r=r*0.01
    C=Basket(S,K,T,sigma,r,rho,'put', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(r)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Risk Free Rate')
# naming the y axis
plt.ylabel('Put Option Price')
plt.title(title+ ' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Correlation between Assets Affect Call Option Price

# %%
S = [50,50]
K= 50
t = 0
T=0.5
sigma=[0.3,0.3]
r = 0.05
M = 10**5
price=[]
param=[]
for rho in range(1,100,1):
    rho=rho*0.01
    C=Basket(S,K,T,sigma,r,rho,'call',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(rho)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Rho')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+ ' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Correlation Between Assets Affect Put Option Price

# %%
S = [50,50]
K= 50
t = 0
T=0.5
sigma=[0.3,0.3]
r = 0.05
M = 10**5
price=[]
param=[]
for rho in range(1,100,1):
    rho=rho*0.01
    C=Basket(S,K,T,sigma,r,rho,'put',M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(rho)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Rho')
# naming the y axis
plt.ylabel('Put Option Price')
plt.title(title+ ' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Volatility Ratio between 2 Assets affects Call Price

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=[11, 9])

fig.suptitle(title+ ' Option')
fig.align_labels()

S = [50,50]
K= 40
t = 0
T=0.5
r = 0.01
sigma1 = 0
sigma2 = 1
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,90,1):
    sigma1+=0.01
    sigma2-=0.01
    C=Basket(S,K,T,[sigma1,sigma2],r,rho,'call', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma1/sigma2)

ax[0].plot(param,price, label = 'ITM', color='r')
ax[0].set_ylabel('Call Option price')

S = [50,50]
K= 50
t = 0
T=0.5
r = 0.01
sigma1 = 0
sigma2 = 1
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,90,1):
    sigma1+=0.01
    sigma2-=0.01
    C=Basket(S,K,T,[sigma1,sigma2],r,rho,'call', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma1/sigma2)

ax[1].plot(param,price, label = 'ATM', color='b')
ax[1].set_ylabel('Call Option price')

S = [50,50]
K= 60
t = 0
T=0.5
r = 0.01
sigma1 = 0
sigma2 = 1
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,90,1):
    sigma1+=0.01
    sigma2-=0.01
    C=Basket(S,K,T,[sigma1,sigma2],r,rho,'call', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma1/sigma2)

ax[2].plot(param,price, label = 'OTM', color='g')
ax[2].set_ylabel('Call Option price')

fig.legend(loc='upper left')
plt.xlabel('Volatility Ratio')
# Out:
# Text(0.5, 0, 'Volatility Ratio')

# %% [markdown]
# ### How Volatility Ratio between 2 Assets affects Put Price

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=[11, 9])

fig.suptitle(title+ ' Option')
fig.align_labels()

S = [50,50]
K= 60
t = 0
T=0.5
r = 0.01
sigma1 = 0
sigma2 = 1
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,90,1):
    sigma1+=0.01
    sigma2-=0.01
    C=Basket(S,K,T,[sigma1,sigma2],r,rho,'put', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma1/sigma2)

ax[0].plot(param,price, label = 'ITM', color='r')
ax[0].set_ylabel('Put Option price')

S = [50,50]
K= 50
t = 0
T=0.5
r = 0.01
sigma1 = 0
sigma2 = 1
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,90,1):
    sigma1+=0.01
    sigma2-=0.01
    C=Basket(S,K,T,[sigma1,sigma2],r,rho,'put', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma1/sigma2)

ax[1].plot(param,price, label = 'ATM', color='b')
ax[1].set_ylabel('Put Option price')

S = [50,50]
K= 38
t = 0
T=0.5
r = 0.01
sigma1 = 0
sigma2 = 1
rho = 0.5
M = 10**5
price=[]
param=[]
for sigma in range(1,90,1):
    sigma1+=0.01
    sigma2-=0.01
    C=Basket(S,K,T,[sigma1,sigma2],r,rho,'put', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(sigma1/sigma2)

ax[2].plot(param,price, label = 'OTM', color='g')
ax[2].set_ylabel('Put Option price')

fig.legend(loc='upper left')
plt.xlabel('Volatility Ratio')
# Out:
# Text(0.5, 0, 'Volatility Ratio')

# %% [markdown]
# ### How Spot Price Ratio between 2 Assets affects Call Price

# %%
S1 = 1 
S2 = 100
K= 50
t = 0
T=0.5
r = 0.01
sigma = [0.3,0.3]
rho = 0.5
M = 10**5
price=[]
param=[]
for S in range(1,96,1):
    S1+=1
    S2-=1
    C=Basket([S1,S2],K,T,sigma,r,rho,'call', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(S1/S2)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Spot Price Ratio')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+ ' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How Spot Price Ratio between 2 Assets affects Put Price

# %%
S1 = 1 
S2 = 100
K= 50
t = 0
T=0.5
r = 0.01
sigma = [0.3,0.3]
rho = 0.5
M = 10**5
price=[]
param=[]
for S in range(1,96,1):
    S1+=1
    S2-=1
    C=Basket([S1,S2],K,T,sigma,r,rho,'put', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(S1/S2)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Spot Price Ratio')
# naming the y axis
plt.ylabel('Put Option Price')
plt.title(title+ ' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How number of Monte Carlo Paths Affect Call Option Price

# %%
S =  [50,50]
K= 50
t = 0
T=0.5
r = 0.01
sigma = [0.3,0.3]
rho = 0.5
price=[]
param=[]
for M in [1,10,50,100,500,1000,5000,10000,50000,100000,500000,1000000]:
    C=Basket(S,K,T,sigma,r,rho,'call', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(M)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Number of Monte Carlo Paths')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+ ' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')

# %% [markdown]
# ### How number of Monte Carlo Paths Affect Put Option Price

# %%
S =  [50,50]
K= 50
t = 0
T=0.5
r = 0.01
sigma = [0.3,0.3]
rho = 0.5
price=[]
param=[]
for M in [1,10,50,100,500,1000,5000,10000,50000,100000,500000,1000000]:
    C=Basket(S,K,T,sigma,r,rho,'put', M, True)
    price.append(C.arithmetic_basket()[0])
    param.append(M)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Number of Monte Carlo Paths')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+ ' Option')
# Out:
# Text(0.5, 1.0, 'Arithmetic Basket Option')
