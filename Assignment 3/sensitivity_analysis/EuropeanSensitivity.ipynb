# %%
import os
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from BlackScholes import BlackScholes
title= 'European'
bs = BlackScholes()

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### How Strike Price Affects Call Option

# %%
S = 50
t = 0
T = 0.5
sigma = 0.2
r = 0.01
q=0
price=[]
param=[]
for K in range(10,100,10):
    C=bs.euro_vanilla(S,K,T,sigma,r,q,'call')
    price.append(C)
    param.append(K)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Strike Price')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'European Option')

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### How Strike Price Affects Put Option

# %%
S = 50
t = 0
T = 0.5
sigma = 0.2
r = 0.01
q=0
price=[]
param=[]
for K in range(10,100,10):
    C=bs.euro_vanilla(S,K,T,sigma,r,q,'put')
    price.append(C)
    param.append(K)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Strike Price')
# naming the y axis
plt.ylabel('Put Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'European Option')

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### How Maturity Affects Call Option

# %%
S = 50
K= 50
t = 0
sigma = 0.2
r = 0.01
q=0
price=[]
param=[]
for T in range(1,40,1):
    T=T*0.2
    C=bs.euro_vanilla(S,K,T,sigma,r,q,'call')
    price.append(C)
    param.append(T)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Maturity')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'European Option')

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### How Maturity Affects Put Option

# %%
S = 50
K= 50
t = 0
sigma = 0.2
r = 0.01
q=0
price=[]
param=[]
for T in range(1,40,1):
    T=T*0.2
    C=bs.euro_vanilla(S,K,T,sigma,r,q,'put')
    price.append(C)
    param.append(T)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Maturity')
# naming the y axis
plt.ylabel('Put Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'European Option')

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### How Volatility Affects Call Option

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=[11, 9])

fig.suptitle(title+ 'Option ')
fig.align_labels()

S = 50
K= 35
T = 0.5
t = 0
sigma = 0.2
r = 0.01
N = 200
q = 0
price=[]
param=[]
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    price.append(bs.euro_vanilla(S,K,T,sigma,r,q,'call'))
    param.append(sigma)   
ax[0].plot(param,price, label = 'ITM', color='r')
ax[0].set_ylabel('Call Option price')

S = 50
K= 50
t = 0
sigma = 0.2
r = 0.01
N = 200
price=[]
param=[]
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    price.append(bs.euro_vanilla(S,K,T,sigma,r,q,'call'))
    param.append(sigma)
ax[1].plot(param,price, label = 'ATM', color='b')
ax[1].set_ylabel('Call Option price')

S = 50
K= 60
t = 0
sigma = 0.2
r = 0.01
N = 200
price=[]
param=[]
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    price.append(bs.euro_vanilla(S,K,T,sigma,r,q,'call'))
    param.append(sigma)
ax[2].plot(param,price, label='OTM',color='g')
ax[2].set_ylabel('Call Option price')

fig.legend(loc='upper left')
plt.xlabel('Volatility')
# Out:
# Text(0.5, 0, 'Volatility')

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### How Volatility Affects Put Option

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=[11, 9])

fig.suptitle(title+ 'Option ')
fig.align_labels()

S = 50
K= 60
T = 0.5
t = 0
sigma = 0.2
r = 0.01
N = 200
q = 0
price=[]
param=[]
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    price.append(bs.euro_vanilla(S,K,T,sigma,r,q,'put'))
    param.append(sigma)   
ax[0].plot(param,price, label = 'ITM', color='r')
ax[0].set_ylabel('Put Option price')

S = 50
K= 50
t = 0
sigma = 0.2
r = 0.01
N = 200
price=[]
param=[]
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    price.append(bs.euro_vanilla(S,K,T,sigma,r,q,'put'))
    param.append(sigma)
ax[1].plot(param,price, label = 'ATM', color='b')
ax[1].set_ylabel('Put Option price')

S = 50
K= 35
t = 0
sigma = 0.2
r = 0.01
N = 200
price=[]
param=[]
price=[]
param=[]
for sigma in range(1,100,1):
    sigma=sigma*0.01
    price.append(bs.euro_vanilla(S,K,T,sigma,r,q,'put'))
    param.append(sigma)
ax[2].plot(param,price, label='OTM',color='g')
ax[2].set_ylabel('Put Option price')

fig.legend(loc='upper left')
plt.xlabel('Volatility')
# Out:
# Text(0.5, 0, 'Volatility')

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### How Risk Free Rate Affects Call Option

# %%
S = 50
K= 50
t = 0
T=0.5
sigma=0.2
q =0
price=[]
param=[]
for r in range(1,40,1):
    r=r*0.01
    C=bs.euro_vanilla(S,K,T,sigma,r,q,'call')
    price.append(C)
    param.append(r)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Risk Free Rate')
# naming the y axis
plt.ylabel('Call Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'European Option')

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### How Risk Free Rate Affects Put Option

# %%
S = 50
K= 50
t = 0
T=0.5
sigma=0.2
q =0
price=[]
param=[]
for r in range(1,40,1):
    r=r*0.01
    C=bs.euro_vanilla(S,K,T,sigma,r,q,'put')
    price.append(C)
    param.append(r)
plt.plot(param,price)
# naming the x axis
plt.xlabel('Risk Free Rate')
# naming the y axis
plt.ylabel('Put Option Price')
plt.title(title+' Option')
# Out:
# Text(0.5, 1.0, 'European Option')
